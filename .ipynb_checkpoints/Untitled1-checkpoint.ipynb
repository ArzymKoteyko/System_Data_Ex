# %%
import json
from matplotlib import pyplot as plt
import pandas as pd
import math
import numpy as np
import faster_than_requests as requests
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/pg/bh1g5q_j7ydbpjfn1bl4tlq00000gn/T/ipykernel_711/2964565290.py in <module>
#       4 import math
#       5 import numpy as np
# ----> 6 import faster_than_requests as requests
#       7 from tqdm import tqdm
#
# ~/Dev/env/lib/python3.9/site-packages/faster_than_requests/__init__.py in <module>
#       5 import nimporter
#       6
# ----> 7 from . faster_than_requests import *
#
# /usr/local/Cellar/python@3.9/3.9.5/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/local/Cellar/python@3.9/3.9.5/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/local/Cellar/python@3.9/3.9.5/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _find_spec(name, path, target)
#
# ~/Dev/env/lib/python3.9/site-packages/nimporter.py in find_spec(cls, fullname, path, target)
#    1148     Python module and a Nim module with the same name are in the same package,
#    1149     the Python module will be imported.
# -> 1150     """
#    1151
#    1152     @classmethod
#
# ~/Dev/env/lib/python3.9/site-packages/nimporter.py in import_nim_code(cls, fullname, path, library)
#     826
#     827             if not module_path.exists(): continue
# --> 828
#     829             build_artifact = NimCompiler.build_artifact(module_path)
#     830
#
# ~/Dev/env/lib/python3.9/site-packages/nimporter.py in compile_nim_code(cls, module_path, build_artifact, library)
#     586             output, errors, warnings, hints = cls.invoke_compiler(nim_args)
#     587
# --> 588         if errors:
#     589             if library:
#     590                 raise NimInvokeException(tmp_cwd, nim_args, errors, output)
#
# ~/Dev/env/lib/python3.9/site-packages/nimporter.py in __init__(self, msg)
#      46         else:
#      47             nim_module, error_msg = msg.split('Error:')
# ---> 48             if len(nim_module.splitlines()) == 0:
#      49                 self.message = msg
#      50                 return
#
# IndexError: list index out of range

# %%
r = requests.get('https://www.edsm.net/api-v1/cube-systems?size={}'.format(100))

# %%
ammount = len(r.json())
print(ammount)
# Out:
# 2375

# %%
Systems_data_frame = pd.DataFrame(columns = ['id', 'distance', 'bodyCount', 'name'])
totalBodyCount = {str(i):0 for i in range(120 + 1)} 

c = 0
for i in r.json():
    Systems_data_frame = Systems_data_frame.append({'id': c, 'distance': i['distance'], 'bodyCount': i['bodyCount'], 'name': i['name']}, ignore_index=True)
    if i['bodyCount'] != None:
        totalBodyCount[str(i['bodyCount'])] += 1
    c += 1

# %%
Systems_data_frame
# Out:
#         id  distance bodyCount         name
# 0        0     66.57        25      LP 1-52
# 1        1     72.51         5    LP 404-66
# 2        2     69.73        32  Terra Mater
# 3        3     62.19        37     Ross 733
# 4        4     83.62        29    LP 387-31
# ...    ...       ...       ...          ...
# 2370  2370     66.33        18  Chontantici
# 2371  2371     53.11        42      LHS 277
# 2372  2372     50.40        20   LU Velorum
# 2373  2373     71.75        16     LTT 4527
# 2374  2374     53.28         4         Atum
#
# [2375 rows x 4 columns]

# %%
plt.figure(figsize = (50,10))

plt.bar(x = totalBodyCount.keys(), height = totalBodyCount.values())
# Out:
# <BarContainer object of 121 artists>

# %%
for i in range(100):
    name = (Systems_data_frame.loc[i])['name']
    r = requests.get('https://www.edsm.net/api-v1/system?systemName={}'.format(name))

# %%
class System_constructor:
    
    system_id = None
    system_name = None
    system_information = None
    tree = None
    urls = None
    
    
    
    
    def __init__(self, system_name):
        
        self.system_name = system_name
        self.system_id   = self.get_id()
        
        
        
        
    def get_id(self):
        
        r = requests.get('https://www.edsm.net/api-v1/systems?systemName={}&showId=1'.format(self.system_name))
        system_id = r.json()[0]['id']
        return system_id
    
    
    
    
    def get_information(self):
        
        request = requests.get('https://www.edsm.net/en/system/bodies/id/{}/name/{}'.format(self.system_id, self.system_name.replace(' ', '+')))
        information = str(request.content)
        information = information.replace('\\n', '')
        information = information.replace('\\r', '')
        information = information.replace('\\t', '')
        information = information.replace(' /', '')
        information = information.replace('    ', '')
        
        self.system_information = information
    
    
    
    
    def find_between_tags(self, content, tag, attribute = ''):
        
        if attribute != '':
            start_tag  = '<' + tag + ' ' + attribute
        else:
            start_tag  = '<' + tag
            
        finish_tag = '</' + tag + '>'

        open_tag   = '<' + tag
        close_tag  = '</' + tag + '>'
        
        start = content.find(start_tag)
        
        result = []
        
        if start == -1:
            return result
        
        else:
            while start != -1:
        
                cursor = start
                simbol = content[cursor]

                while simbol != '>':
                    cursor += 1
                    simbol = content[cursor]
                cursor += 1

                content_start = cursor
                counter = 1
                while counter != 0:
                    if content[cursor:cursor+len(open_tag)] == open_tag:
                        counter += 1
                    elif content[cursor:cursor+len(close_tag)] == close_tag:
                        counter -= 1
                    cursor += 1
                content_end = cursor - 1

                result.append(content[content_start:content_end])
                content = content[0:start] + content[content_end + len(close_tag):len(content)]
                start = content.find(start_tag)
        return result
    
    
    
    
    def find_attribute(self, content, attribute):
        
        start = content.find(attribute)
        Res = []
        
        if start == -1:
            return Res  
        
        while start != -1:
            
            start += len(attribute) + 2 
            cursor = start
            c = 1
        
            while c != 0:
                if content[cursor] == '"':
                    c -= 1
                cursor += 1
            finish = cursor - 1

            Res.append(content[start:finish])
            content = content[finish::]
            start = content.find(attribute)
            
        return Res
    
    
    
    
    def find_name(self, content):
        
        result = self.find_between_tags(content, 'a', 'href="')
        if len(result) != 0:
            return self.find_between_tags(content, 'a', 'href="')[0]
        else:
            return self.find_between_tags(content, 'div', 'class="card-header"')[0]
    
    
    
    
    def find_url(self, content):
        
        start = content.find('<a ')
    
        i = start
        while content[i] != '>':
            i += 1
        
        finish = i - 1
        start += 9
    
        return 'https://www.edsm.net{}'.format(content[start:finish])


    
    
    def alocate_tree(self, content):
        
        items = self.find_between_tags(content, 'div', 'class="container mb-4"')
        full_tree = {}
        full_urls = {}
        for i in items:
            tree, urls = self.construct_tree(i)
            full_tree |= tree
            full_urls |= urls
            
        self.tree = full_tree
        self.urls = full_urls
            
        
    def construct_tree(self, content, tree = {}, urls = {}):
    
        try:
            information = self.find_between_tags(content, 'div', 'class="card mb-0"')[0]
        except:
            return None
        name = self.find_name(information)
        
        url = self.find_url(information)
        urls[name] = url
        
        children = self.find_between_tags(content, 'div', 'class="child"')
        
        if len(children) != 0:
            
            tree[name] = []
            for child in children:
                
                child_name = self.find_name(child)
                tree[name].append(child_name)
                self.construct_tree(child, tree = tree, urls = urls)
                
        return tree, urls
       
    
    
    
    def collect_body_row_information(self, url):
        
        request = requests.get(url)
        information = str(request.content)
        information = information.replace('\\n', '')
        information = information.replace('\\r', '')
        information = information.replace('\\t', '')
        information = information.replace(' /', '')
        information = information.replace('    ', '')
        information = information.replace('\\xc2\\xb0', '')
        information = self.find_between_tags(information, 'div', 'class="col-lg-8"')[0]
        information = self.find_between_tags(information, 'div', 'class="row"')
    
        Data = {}
    
        for item in information:
            
            if len(self.find_between_tags(item, 'div', 'class="col-lg-4"')) != 0:
                
                parameter = self.find_between_tags(item, 'div', 'class="col-lg-4"')[0]
                parameter = parameter[0:-1]
                value = self.find_between_tags(item, 'div', 'class="col-lg-8"')[0]
                
                Data[parameter] = value
                
        Result = {}
                
        for key in Data.keys():
            
            
            if key == 'Type':
                Result['Type'] = self.find_between_tags(Data[key], 'strong')[0]
                surface = self.find_between_tags(Data[key], 'em')
                if len(surface) != 0:
                    Result['Surface'] = surface[0]
                    
                    
            elif key == 'Full Spectral Class':
                Result[key] = self.find_between_tags(Data[key], 'em')[0]       
                Result[key] += ' ' + self.find_between_tags(Data['Luminosity'], 'strong')[0]
                
                
            elif key == 'First scanned for EDSM by':
                try:
                    Result['First scanned'] = self.find_between_tags(Data[key], 'span')[0]
                except: 
                    try:
                        Result['First scanned'] = self.find_between_tags(Data[key], 'a')[0]
                    except:
                        pass
                
                
            elif key == 'First mapped for EDSM by':
                try:
                    Result['First mapped'] = self.find_between_tags(Data[key], 'span')[0]
                except:
                    try:
                        Result['First mapped'] = self.find_between_tags(Data[key], 'a')[0]
                    except:
                        pass
                
                
            elif key == 'Solid composition' or key == 'Atmosphere composition':
                info = Data[key].split('<br>')
                info.pop(-1)
                for item in info:
                    p = item.split('%')
                    Result[p[1]] = float(p[0]) / 100
            
            
            elif key == 'Rotational period':
                Result['Rotational period'] = self.find_between_tags(Data[key], 'strong')[0]
                locked = self.find_between_tags(Data[key], 'em')
                if len(locked) != 0:
                    Result['Tidally Locked'] = True
                else:
                    Result['Tidally Locked'] = False
                    
                    
            elif key == 'Materials':
                materials_names = self.find_between_tags(Data[key], 'strong')
                materials_composition = self.find_between_tags(Data[key], 'small')
                badges = self.find_attribute(Data[key], 'class')
                for index in range(len(materials_names)):
                    Result[materials_names[index]] = materials_composition[index]
                    Result[materials_names[index] + ' badge'] = badges[index].replace('badge badge-material badge-', '')
                    
                    
            else:
                info = self.find_between_tags(Data[key], 'strong')
                if len(info) != 0:
                    Result[key] = info[0]
                    
                    
        
        return Result
        
        
        
        
    def proced_all_information(self):
        
        self.get_information()
        self.construct_tree(self.system_information)
            
        Result = {}
            
        for key in self.urls.keys():
            
            try:
                Result[key] = self.collect_body_row_information(self.urls[key])
            except:
                print('Error acured')
                print('Body name', key)
                print('Body url', self.urls[key])
            else:
                Result[key]['url'] = self.urls[key]
            
        self.system_information = Result
        
        
        
    
    def full(self):
        S = self.system_information
        for key in S.keys():
            print('\t\t', key)
            print()
            for k in S[key].keys():
                print(k, ' ' * (28 - len(k)), S[key][k])
            print('-'*120)
            
    
    
    
    def mini(self):
        print(self.system_name, self.system_id)
        for key in self.tree.keys():
            print(key, end = ' ' * (30 - len(key)))
            print(self.tree[key])
    
i = 13
i = 5
i = 22
A = System_constructor((Systems_data_frame.loc[i])['name'])
A.get_information()

# %%
A.get_information()
A.alocate_tree(A.system_information)
print(A.system_name, A.system_id)
print(Systems_data_frame.loc[i])
print()
A.mini()
# Out:
# Agwe 18056
# id              22
# distance     83.85
# bodyCount       10
# name          Agwe
# Name: 22, dtype: object
#
# Agwe 18056
# Agwe                          ['Agwe A A Belt', 'Agwe A B Belt', 'Agwe A 1', 'Agwe A 2']
# Agwe A 1                      ['Agwe A 1 a']
# Gl 338.1 B                    ['Agwe B 1', 'Agwe B 2', 'Agwe B 3', 'Agwe B 4']
# Agwe B 2                      ['Agwe B 2 a']

# %%
A.proced_all_information()
print(A.full())
# Out:
# 		 Agwe
#
# Type                          K (Yellow-Orange) Star
# Surface                       (Scoopable)
# Distance to arrival           0 ls
# First scanned                 Localdeck
# Estimated value               1,213 cr
# Age                           6,344 million years
# Full Spectral Class           K3 V
# Luminosity                    V
# Solar masses                  0.6953
# Solar radius                  0.7828
# Surface temperature           4,712 K
# Absolute magnitude            8.2321
# Orbital period                43,960.5 d
# Semi major axis               6.48 au
# Orbital eccentricity          0.1371
# Orbital inclination           -11.21
# Arg of periapsis              357.86
# Rotational period             2.3 d
# Tidally Locked                False
# Axial Tilt                    0.1909
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390984/nameB/Agwe
# ------------------------------------------------------------------------------------------------------------------------
# 		 Agwe A 1
#
# Type                          Class I gas giant
# Distance to arrival           1,739 ls
# First scanned                 Localdeck
# Estimated value               4,646 cr
# Earth masses                  330.7753
# Radius                        72,480 km
# Reserve level                 Common
# Surface temperature           116 K
# Gravity                        2.56 G
# Volcanism                     No volcanism
# Atmosphere                    No atmosphere
# Hydrogen                      0.7261
# Helium                        0.27390000000000003
# Orbital period                44.9 d
# Semi major axis               0.00 au
# Orbital eccentricity          0.1960
# Orbital inclination           7.94
# Arg of periapsis              104.28
# Rotational period             2.9 d
# Tidally Locked                False
# Axial Tilt                    -0.2819
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390991/nameB/Agwe+A+1
# ------------------------------------------------------------------------------------------------------------------------
# 		 Agwe A 1 a
#
# Type                          Icy body
# Surface                       (Landable)
# Distance to arrival           1,739 ls
# First scanned                 Localdeck
# First mapped                  SyndicateUA
# Estimated value               500 cr
# Efficiency target             4
# Earth masses                  0.0056
# Radius                        1,557 km
# Surface temperature           77 K
# Gravity                        0.09 G
# Ice                           0.8305
# Rock                          0.1543
# Metal                         0.0152
# Volcanism                     Major Water Geysers
# Atmosphere                    No atmosphere
# Orbital period                1.3 d
# Semi major axis               0.00 au
# Orbital eccentricity          0.0044
# Orbital inclination           -0.22
# Arg of periapsis              216.57
# Rotational period             1.3 d
# Tidally Locked                True
# Axial Tilt                    -0.1095
# S                             (27.3%)
# S badge                       info
# C                             (22.9%)
# C badge                       info
# P                             (14.7%)
# P badge                       info
# Fe                            (12.2%)
# Fe badge                      info
# Ni                            (9.2%)
# Ni badge                      info
# Mn                            (5.0%)
# Mn badge                      success
# Ge                            (3.5%)
# Ge badge                      success
# Zn                            (3.3%)
# Zn badge                      success
# Y                             (0.7%)
# Y badge                       danger
# W                             (0.7%)
# W badge                       warning
# Hg                            (0.5%)
# Hg badge                      warning
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390988/nameB/Agwe+A+1+a
# ------------------------------------------------------------------------------------------------------------------------
# 		 Agwe A 2
#
# Type                          Class I gas giant
# Distance to arrival           1,747 ls
# First scanned                 Localdeck
# First mapped                  Tyranojsus
# Estimated value               2,796 cr
# Efficiency target             9
# Earth masses                  2.6670
# Radius                        15,265 km
# Reserve level                 Common
# Surface temperature           78 K
# Gravity                        0.47 G
# Volcanism                     No volcanism
# Atmosphere                    No atmosphere
# Hydrogen                      0.7261
# Helium                        0.27390000000000003
# Orbital period                44.9 d
# Semi major axis               0.02 au
# Orbital eccentricity          0.1960
# Orbital inclination           7.94
# Arg of periapsis              284.28
# Rotational period             45.1 d
# Tidally Locked                False
# Axial Tilt                    -0.1601
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390989/nameB/Agwe+A+2
# ------------------------------------------------------------------------------------------------------------------------
# 		 Gl 338.1 B
#
# Type                          M (Red dwarf) Star
# Surface                       (Scoopable)
# Distance to arrival           12,745 ls
# First scanned                 Localdeck
# Estimated value               1,205 cr
# Age                           10,922 million years
# Full Spectral Class           M6 V
# Luminosity                    V
# Solar masses                  0.2578
# Solar radius                  0.4339
# Surface temperature           2,510 K
# Absolute magnitude            10.2636
# Orbital period                43,960.5 d
# Semi major axis               17.52 au
# Orbital eccentricity          0.1371
# Orbital inclination           -11.21
# Arg of periapsis              177.86
# Rotational period             2.0 d
# Tidally Locked                False
# Axial Tilt                    0.2436
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390981/nameB/Gl+338.1+B
# ------------------------------------------------------------------------------------------------------------------------
# 		 Agwe B 1
#
# Type                          High metal content world
# Distance to arrival           13,215 ls
# First scanned                 Localdeck
# First mapped                  Bruno Esparza
# Estimated value               14,207 cr
# Efficiency target             6
# Earth masses                  0.4018
# Radius                        4,690 km
# Surface temperature           99 K
# Surface pressure              1.91902079 Atmospheres
# Gravity                        0.74 G
# Rock                          0.6435
# Metal                         0.31579999999999997
# Ice                           0.0407
# Volcanism                     No volcanism
# Atmosphere                    Argon-rich
# Nitrogen                      0.9925
# Argon                         0.0072
# Orbital period                678.5 d
# Semi major axis               0.96 au
# Orbital eccentricity          0.0033
# Orbital inclination           0.05
# Arg of periapsis              187.48
# Rotational period             0.7 d
# Tidally Locked                False
# Axial Tilt                    -0.0635
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390982/nameB/Agwe+B+1
# ------------------------------------------------------------------------------------------------------------------------
# 		 Agwe B 2
#
# Type                          Icy body
# Distance to arrival           13,089 ls
# First scanned                 Localdeck
# Estimated value               500 cr
# Earth masses                  0.4048
# Radius                        5,882 km
# Surface temperature           87 K
# Surface pressure              51.69081668 Atmospheres
# Gravity                        0.48 G
# Ice                           0.6743000000000001
# Rock                          0.217
# Metal                         0.10859999999999999
# Volcanism                     No volcanism
# Atmosphere                    Thick Argon-rich
# Nitrogen                      0.8974
# Argon                         0.1025
# Orbital period                1,137.7 d
# Semi major axis               1.36 au
# Orbital eccentricity          0.0034
# Orbital inclination           -0.02
# Arg of periapsis              146.64
# Rotational period             1.4 d
# Tidally Locked                False
# Axial Tilt                    2.1810
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390983/nameB/Agwe+B+2
# ------------------------------------------------------------------------------------------------------------------------
# 		 Agwe B 2 a
#
# Type                          Icy body
# Surface                       (Landable)
# Distance to arrival           13,089 ls
# First scanned                 Localdeck
# First mapped                  El Vert
# Estimated value               500 cr
# Efficiency target             6
# Earth masses                  0.0249
# Radius                        2,571 km
# Surface temperature           75 K
# Gravity                        0.15 G
# Ice                           0.8794
# Rock                          0.1038
# Metal                         0.0168
# Volcanism                     No volcanism
# Atmosphere                    No atmosphere
# Orbital period                19.3 d
# Semi major axis               0.00 au
# Orbital inclination           -83.66
# Arg of periapsis              35.54
# Rotational period             19.8 d
# Tidally Locked                True
# Axial Tilt                    -0.3422
# S                             (27.5%)
# S badge                       info
# C                             (23.1%)
# C badge                       info
# P                             (14.8%)
# P badge                       info
# Fe                            (12.0%)
# Fe badge                      info
# Ni                            (9.1%)
# Ni badge                      info
# Cr                            (5.4%)
# Cr badge                      success
# Se                            (4.3%)
# Se badge                      success
# As                            (1.4%)
# As badge                      success
# Nb                            (0.8%)
# Nb badge                      warning
# Ru                            (0.7%)
# Ru badge                      danger
# Sn                            (0.7%)
# Sn badge                      warning
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390985/nameB/Agwe+B+2+a
# ------------------------------------------------------------------------------------------------------------------------
# 		 Agwe B 3
#
# Type                          Icy body
# Surface                       (Landable)
# Distance to arrival           11,908 ls
# First scanned                 Localdeck
# Estimated value               500 cr
# Earth masses                  0.1920
# Radius                        4,674 km
# Surface temperature           68 K
# Surface pressure              0.00717651 Atmospheres
# Gravity                        0.36 G
# Ice                           0.6862
# Rock                          0.21050000000000002
# Metal                         0.1033
# Volcanism                     No volcanism
# Atmosphere                    Thin Neon-rich
# Nitrogen                      0.851
# Neon                          0.149
# Orbital period                1,662.4 d
# Semi major axis               1.75 au
# Orbital eccentricity          0.0013
# Orbital inclination           -0.28
# Arg of periapsis              171.61
# Rotational period             1.6 d
# Tidally Locked                False
# Axial Tilt                    -0.2148
# S                             (23.1%)
# S badge                       info
# C                             (19.4%)
# C badge                       info
# Fe                            (16.0%)
# Fe badge                      info
# P                             (12.4%)
# P badge                       info
# Ni                            (12.1%)
# Ni badge                      info
# Cr                            (7.2%)
# Cr badge                      success
# Se                            (3.6%)
# Se badge                      success
# Ge                            (3.3%)
# Ge badge                      success
# Cd                            (1.2%)
# Cd badge                      warning
# Mo                            (1.0%)
# Mo badge                      warning
# Tc                            (0.6%)
# Tc badge                      danger
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390987/nameB/Agwe+B+3
# ------------------------------------------------------------------------------------------------------------------------
# 		 Agwe B 4
#
# Type                          Icy body
# Distance to arrival           13,752 ls
# First scanned                 Localdeck
# Estimated value               500 cr
# Earth masses                  0.4354
# Radius                        6,038 km
# Surface temperature           86 K
# Surface pressure              745.87507525 Atmospheres
# Gravity                        0.49 G
# Ice                           0.6851999999999999
# Rock                          0.2112
# Metal                         0.10369999999999999
# Volcanism                     No volcanism
# Atmosphere                    Thick Argon-rich
# Nitrogen                      0.9915
# Argon                         0.0085
# Orbital period                2,461.4 d
# Semi major axis               2.27 au
# Orbital eccentricity          0.0020
# Orbital inclination           -2.18
# Arg of periapsis              110.00
# Rotational period             1.1 d
# Tidally Locked                False
# Axial Tilt                    0.1784
# url                           https://www.edsm.net/en/system/bodies/id/18056/name/Agwe/details/idB/11390990/nameB/Agwe+B+4
# ------------------------------------------------------------------------------------------------------------------------
# None

# %%
for i in tqdm(range(30)):
    A = System_constructor((Systems_data_frame.loc[i])['name'])
    A.get_information()
    A.alocate_tree(A.system_information)
    A.proced_all_information()
# Out:
#   0%|                                                                    | 0/30 [00:00<?, ?it/s]
# Error acured
# Body name Ross 249 1
# Body url https://www.edsm.net/en/system/bodies/id/1550/name/Ross+249/details/idB/138827/nameB/Ross+249+1
#  20%|████████████                                                | 6/30 [07:31<29:22, 73.44s/it]
# Error acured
# Body name LP 347-5 B 12 d
# Body url https://www.edsm.net/en/system/bodies/id/4000/name/LP+347-5/details/idB/8864804/nameB/LP+347-5+B+12+d
# Error acured
# Body name CR Draco 4 e
# Body url https://www.edsm.net/en/system/bodies/id/18450/name/CR+Draco/details/idB/110533/nameB/CR+Draco+4+e
# Error acured
# Body name CR Draco 6
# Body url https://www.edsm.net/en/system/bodies/id/18450/name/CR+Draco/details/idB/110593/nameB/CR+Draco+6
# Error acured
# Body name CR Draco 7
# Body url https://www.edsm.net/en/system/bodies/id/18450/name/CR+Draco/details/idB/110608/nameB/CR+Draco+7
# Error acured
# Body name Gliese 815 B
# Body url https://www.edsm.net/en/system/bodies/id/25852/name/V1396+Cygni/details/idB/18793127/nameB/Gliese+815+B
# Error acured
# Body name Alrai Sector KW-W a1-1
# Body url https://www.edsm.net/en/system/bodies/id/142254/name/Alrai+Sector+KW-W+a1-1/details/idB/603962/nameB/Alrai+Sector+KW-W+a1-1
# Error acured
# Body name Hsien Baji
# Body url https://www.edsm.net/en/system/bodies/id/11732/name/Hsien+Baji/details/idB/102264/nameB/Hsien+Baji
# Error acured
# Body name Hsien Baji 2
# Body url https://www.edsm.net/en/system/bodies/id/11732/name/Hsien+Baji/details/idB/1316819/nameB/Hsien+Baji+2
# Error acured
# Body name Hsien Baji 3
# Body url https://www.edsm.net/en/system/bodies/id/11732/name/Hsien+Baji/details/idB/1316827/nameB/Hsien+Baji+3
# Error acured
# Body name Hsien Baji 4
# Body url https://www.edsm.net/en/system/bodies/id/11732/name/Hsien+Baji/details/idB/1316835/nameB/Hsien+Baji+4
# Error acured
# Body name Piscium Sector VK-N a7-2 1
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941335/nameB/Piscium+Sector+VK-N+a7-2+1
# Error acured
# Body name Piscium Sector VK-N a7-2 2
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941342/nameB/Piscium+Sector+VK-N+a7-2+2
# Error acured
# Body name Piscium Sector VK-N a7-2 3
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941349/nameB/Piscium+Sector+VK-N+a7-2+3
# Error acured
# Body name Piscium Sector VK-N a7-2 3 a
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941352/nameB/Piscium+Sector+VK-N+a7-2+3+a
# Error acured
# Body name Piscium Sector VK-N a7-2 4
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941362/nameB/Piscium+Sector+VK-N+a7-2+4
# Error acured
# Body name Piscium Sector VK-N a7-2 4 a
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941367/nameB/Piscium+Sector+VK-N+a7-2+4+a
# Error acured
# Body name Piscium Sector VK-N a7-2 6
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941394/nameB/Piscium+Sector+VK-N+a7-2+6
# Error acured
# Body name Piscium Sector VK-N a7-2 6 a
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941401/nameB/Piscium+Sector+VK-N+a7-2+6+a
# Error acured
# Body name Piscium Sector VK-N a7-2 7
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941413/nameB/Piscium+Sector+VK-N+a7-2+7
# Error acured
# Body name Piscium Sector VK-N a7-2 8
# Body url https://www.edsm.net/en/system/bodies/id/108206/name/Piscium+Sector+VK-N+a7-2/details/idB/2941417/nameB/Piscium+Sector+VK-N+a7-2+8
# Error acured
# Body name Jastreb Sector CB-X b1-4
# Body url https://www.edsm.net/en/system/bodies/id/25028/name/Jastreb+Sector+CB-X+b1-4/details/idB/537842/nameB/Jastreb+Sector+CB-X+b1-4
# Error acured
# Body name Jastreb Sector CB-X b1-4 4 a
# Body url https://www.edsm.net/en/system/bodies/id/25028/name/Jastreb+Sector+CB-X+b1-4/details/idB/4207142/nameB/Jastreb+Sector+CB-X+b1-4+4+a
# Error acured
# Body name Jastreb Sector CB-X b1-4 5
# Body url https://www.edsm.net/en/system/bodies/id/25028/name/Jastreb+Sector+CB-X+b1-4/details/idB/4207139/nameB/Jastreb+Sector+CB-X+b1-4+5
# Error acured
# Body name Jastreb Sector CB-X b1-4 5 a
# Body url https://www.edsm.net/en/system/bodies/id/25028/name/Jastreb+Sector+CB-X+b1-4/details/idB/4207140/nameB/Jastreb+Sector+CB-X+b1-4+5+a
